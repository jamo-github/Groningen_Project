# %% [markdown]
# # Capstone Project Notebook
#
# ### J. Momand
#
# This Notebook will be mainly used for the capstone project of the IBM Data Science Professional Certificate by Coursera

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
